# %%
import pandas as pd
import numpy as np

# %%
people = {
    'first': ['Hari', 'Carey', np.nan, None, 'NA'],
    'last': ['Aineri', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': ['HariAineri@email.com', 'CareySchafer@email.com', None, 'abc@email.com', 'NA'],
    'Age': [34, 35, 36, None, 'NA']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com    34
# 1  Carey  Schafer  CareySchafer@email.com    35
# 2    NaN      NaN                    None    36
# 3   None      NaN           abc@email.com  None
# 4     NA  Missing                      NA    NA

# %%
df.dropna()
# Out:
#    first     last                   email Age
# 0   Hari   Aineri    HariAineri@email.com  34
# 1  Carey  Schafer  CareySchafer@email.com  35
# 4     NA  Missing                      NA  NA

# %%
df.dropna(axis='index', how='any')
# Out:
#    first     last                   email Age
# 0   Hari   Aineri    HariAineri@email.com  34
# 1  Carey  Schafer  CareySchafer@email.com  35
# 4     NA  Missing                      NA  NA

# %%
df.dropna(axis='columns', how='all')
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com  34.0
# 1  Carey  Schafer  CareySchafer@email.com  35.0
# 2    NaN      NaN                    None  36.0
# 3   None      NaN           abc@email.com   NaN
# 4    NaN      NaN                     NaN   NaN

# %%
df.dropna(axis='index', how='any', subset=['email'])
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com    34
# 1  Carey  Schafer  CareySchafer@email.com    35
# 3   None      NaN           abc@email.com  None
# 4     NA  Missing                      NA    NA

# %%
df.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com    34
# 1  Carey  Schafer  CareySchafer@email.com    35
# 3   None      NaN           abc@email.com  None
# 4     NA  Missing                      NA    NA

# %%
df.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com    34
# 1  Carey  Schafer  CareySchafer@email.com    35
# 3   None      NaN           abc@email.com  None
# 4     NA  Missing                      NA    NA

# %%
pd.set_option('future.no_silent_downcasting', True)

# %%
df = pd.DataFrame(people)
df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)

# %%
df
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com  34.0
# 1  Carey  Schafer  CareySchafer@email.com  35.0
# 2    NaN      NaN                    None  36.0
# 3   None      NaN           abc@email.com   NaN
# 4    NaN      NaN                     NaN   NaN

# %%
df.dropna(axis='index', how='any')
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com  34.0
# 1  Carey  Schafer  CareySchafer@email.com  35.0

# %%
df.isna()
# Out:
#    first   last  email    Age
# 0  False  False  False  False
# 1  False  False  False  False
# 2   True   True   True  False
# 3   True   True  False   True
# 4   True   True   True   True

# %%
df.fillna('MISSING')
# Out:
#      first     last                   email      Age
# 0     Hari   Aineri    HariAineri@email.com     34.0
# 1    Carey  Schafer  CareySchafer@email.com     35.0
# 2  MISSING  MISSING                 MISSING     36.0
# 3  MISSING  MISSING           abc@email.com  MISSING
# 4  MISSING  MISSING                 MISSING  MISSING

# %%
df.fillna(0)
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com  34.0
# 1  Carey  Schafer  CareySchafer@email.com  35.0
# 2      0        0                       0  36.0
# 3      0        0           abc@email.com   0.0
# 4      0        0                       0   0.0

# %%
df.dtypes
# Out:
# first    object
# last     object
# email    object
# Age      object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
df['Age'].mean()
# Out:
# 35.0

# %%
df.loc[3, 'Age'] = 10

# %%
df
# Out:
#    first     last                   email  Age
# 0   Hari   Aineri    HariAineri@email.com   34
# 1  Carey  Schafer  CareySchafer@email.com   35
# 2    NaN      NaN                    None   36
# 3   None      NaN           abc@email.com   10
# 4    NaN      NaN                     NaN  NaN

# %%
df['Age'].mean()
# Out:
# 28.75

# %%
filt = df['email'] == 'abc@email.com'
df.loc[filt, 'Age'] = 20
df
# Out:
#    first     last                   email  Age
# 0   Hari   Aineri    HariAineri@email.com   34
# 1  Carey  Schafer  CareySchafer@email.com   35
# 2    NaN      NaN                    None   36
# 3   None      NaN           abc@email.com   20
# 4    NaN      NaN                     NaN  NaN

# %%
df['Age'] = df['Age'].astype(float)

# %%
df
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com  34.0
# 1  Carey  Schafer  CareySchafer@email.com  35.0
# 2    NaN      NaN                    None  36.0
# 3   None      NaN           abc@email.com  20.0
# 4    NaN      NaN                     NaN   NaN

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# Age      float64
# dtype: object

# %%
df['Age'].mean()
# Out:
# 31.25

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   31.250000
# std     7.544314
# min    20.000000
# 25%    30.500000
# 50%    34.500000
# 75%    35.250000
# max    36.000000

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qid')

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 1     NaN
# 2      18
# 3      27
# 4      12
# 5       6
# 6      21
# 7       4
# 8       5
# 9      20
# 10      6
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].value_counts()
# Out:
# YearsCode
# 10                    6521
# 5                     5415
# 6                     4893
# 8                     4879
# 7                     4800
# 4                     4466
# 15                    4336
# 3                     4269
# 20                    4021
# 12                    3471
# 9                     3130
# 2                     2826
# 25                    2685
# 13                    2601
# 11                    2519
# 14                    2278
# 30                    2078
# 16                    1842
# 18                    1690
# 17                    1544
# 23                    1327
# 40                    1302
# 1                     1294
# 22                    1210
# 35                    1118
# Less than 1 year       968
# 24                     959
# 19                     826
# 21                     761
# 28                     715
# 27                     710
# 26                     706
# 33                     496
# 32                     444
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 'Less than 1 year', '16', '33', '22',
#        '30', '32', '7', '35', '28', '40', '17', '29', '19',
#        'More than 50 years', '9', '38', '26', '34', '25', '2', '45', '23',
#        '31', '43', '1', '48', '41', '50', '39', '42', '37', '36', '44',
#        '46', '49', '47'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 0, '16', '33', '22', '30', '32', '7',
#        '35', '28', '40', '17', '29', '19', 51, '9', '38', '26', '34',
#        '25', '2', '45', '23', '31', '43', '1', '48', '41', '50', '39',
#        '42', '37', '36', '44', '46', '49', '47'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 13.966855378281009

# %%
df['YearsCode'].median()
# Out:
# 11.0
