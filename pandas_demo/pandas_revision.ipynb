# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 78)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
df.tail()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89179     25-34 years old  Employed, full-time;Independent contractor, fr...
# 89180     18-24 years old             Student, full-time;Employed, part-time
# 89181   Prefer not to say                                I prefer not to say
# 89182  Under 18 years old             Employed, part-time;Student, part-time
# 89183     35-44 years old                                Employed, full-time
#
#                                  RemoteWork  \
# 89179                                Remote
# 89180  Hybrid (some remote, some in-person)
# ...

# %%
df.tail(10)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89174       89175  I agree  I am a developer by profession
# 89175       89176  I agree  I am a developer by profession
# 89176       89177  I agree  I am a developer by profession
# 89177       89178  I agree  I am a developer by profession
# 89178       89179  I agree  I am a developer by profession
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89174     18-24 years old                                Employed, full-time
# 89175     25-34 years old                                Employed, full-time
# 89176     18-24 years old                                 Student, full-time
# ...

# %%
people = {
    "first": ["Hari", "Carey"],
    "last": ["Aineri", "Schafer"],
    "email": ["HariAineri@gmail.com", "CareySchafer@gmail.com"]
}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#    first     last                   email
# 0   Hari   Aineri    HariAineri@gmail.com
# 1  Carey  Schafer  CareySchafer@gmail.com

# %%
people_df['email']
# Out:
# 0      HariAineri@gmail.com
# 1    CareySchafer@gmail.com
# Name: email, dtype: object

# %%
people_df.email
# Out:
# 0      HariAineri@gmail.com
# 1    CareySchafer@gmail.com
# Name: email, dtype: object

# %%
people_df[['last', 'email']]
# Out:
#       last                   email
# 0   Aineri    HariAineri@gmail.com
# 1  Schafer  CareySchafer@gmail.com

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
people_df.iloc[0]
# Out:
# first                    Hari
# last                   Aineri
# email    HariAineri@gmail.com
# Name: 0, dtype: object

# %%
type(people_df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
people_df.iloc[0]['email']
# Out:
# 'HariAineri@gmail.com'

# %%
people_df.iloc[0, 0]
# Out:
# 'Hari'

# %%
people_df.iloc[[0, 1]]
# Out:
#    first     last                   email
# 0   Hari   Aineri    HariAineri@gmail.com
# 1  Carey  Schafer  CareySchafer@gmail.com

# %%
type(people_df.iloc[[0, 1]])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.iloc[[0, 1], [1]]
# Out:
#       last
# 0   Aineri
# 1  Schafer

# %%
type(people_df.iloc[[0, 1], [1, 2]])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.iloc[[0, 1], 2]
# Out:
# 0      HariAineri@gmail.com
# 1    CareySchafer@gmail.com
# Name: email, dtype: object

# %%
type(people_df.iloc[[0, 1], 2])
# Out:
# pandas.core.series.Series

# %%
people_df.loc[0]
# Out:
# first                    Hari
# last                   Aineri
# email    HariAineri@gmail.com
# Name: 0, dtype: object

# %%
type(people_df.loc[0])
# Out:
# pandas.core.series.Series

# %%
people_df.loc[0, 'email']
# Out:
# 'HariAineri@gmail.com'

# %%
people_df.loc[[0, 1], 'email']
# Out:
# 0      HariAineri@gmail.com
# 1    CareySchafer@gmail.com
# Name: email, dtype: object

# %%
type(people_df.loc[[0, 1], 'email'])
# Out:
# pandas.core.series.Series

# %%
people_df.loc[[0, 1], ['email']]
# Out:
#                     email
# 0    HariAineri@gmail.com
# 1  CareySchafer@gmail.com

# %%
type(people_df.loc[[0, 1], ['email']])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.loc[[0, 1], ['last', 'email']]
# Out:
#       last                   email
# 0   Aineri    HariAineri@gmail.com
# 1  Schafer  CareySchafer@gmail.com

# %%
type(people_df.loc[[0, 1], ['last', 'email']])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.loc[0:2, 'first':'email']
# Out:
#    first     last                   email
# 0   Hari   Aineri    HariAineri@gmail.com
# 1  Carey  Schafer  CareySchafer@gmail.com

# %%
people_df.loc[0:1, 'email']
# Out:
# 0      HariAineri@gmail.com
# 1    CareySchafer@gmail.com
# Name: email, dtype: object

# %%
type(people_df.loc[0:2, 'first':'email'])
# Out:
# pandas.core.frame.DataFrame

# %%
people_df.loc[0:2, 'email']
# Out:
# 0      HariAineri@gmail.com
# 1    CareySchafer@gmail.com
# Name: email, dtype: object

# %%
df['MainBranch'].value_counts()
# Out:
# MainBranch
# I am a developer by profession                                                           67237
# I am not primarily a developer, but I write code sometimes as part of my work/studies     8954
# I am learning to code                                                                     4961
# I code primarily as a hobby                                                               4960
# I used to be a developer by profession, but no longer am                                  1861
# None of these                                                                             1211
# Name: count, dtype: int64

# %%
df['MainBranch'].value_counts()['I am a developer by profession']
# Out:
# 67237

# %%
df['MainBranch'].value_counts().loc['I am a developer by profession']
# Out:
# 67237

# %%
# %matplotlib inline

# %%
df['MainBranch'].value_counts().plot()
# Out:
# <Axes: xlabel='MainBranch'>

# %%
people_df
# Out:
#    first     last                   email
# 0   Hari   Aineri    HariAineri@gmail.com
# 1  Carey  Schafer  CareySchafer@gmail.com

# %%
people_df.set_index('email', inplace=True)

# %%
people_df
# Out:
#                         first     last
# email
# HariAineri@gmail.com     Hari   Aineri
# CareySchafer@gmail.com  Carey  Schafer

# %%
people_df.loc['HariAineri@gmail.com']
# Out:
# first      Hari
# last     Aineri
# Name: HariAineri@gmail.com, dtype: object

# %%
people_df.iloc[0, 1]
# Out:
# 'Aineri'

# %%
people_df.loc['HariAineri@gmail.com']['first']
# Out:
# 'Hari'

# %%
people_df.loc['HariAineri@gmail.com'].loc['first']
# Out:
# 'Hari'

# %%
people_df.sort_index()
# Out:
#                         first     last
# email
# CareySchafer@gmail.com  Carey  Schafer
# HariAineri@gmail.com     Hari   Aineri

# %%
people_df.reset_index(inplace=True)

# %%
people_df
# Out:
#                     email  first     last
# 0    HariAineri@gmail.com   Hari   Aineri
# 1  CareySchafer@gmail.com  Carey  Schafer

# %%
people_df.sort_index()
# Out:
#                     email  first     last
# 0    HariAineri@gmail.com   Hari   Aineri
# 1  CareySchafer@gmail.com  Carey  Schafer

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
filt = (people_df['last'] == 'Aineri')

# %%
people_df[filt]
# Out:
#                   email first    last
# 0  HariAineri@gmail.com  Hari  Aineri

# %%
people_df.loc[filt]
# Out:
#                   email first    last
# 0  HariAineri@gmail.com  Hari  Aineri

# %%
people_df.loc[filt, 'email']
# Out:
# 0    HariAineri@gmail.com
# Name: email, dtype: object

# %%
filt = (people_df['last'] == 'Aineri') & (people_df['first'] == 'Hari')

# %%
people_df.loc[filt]
# Out:
#                   email first    last
# 0  HariAineri@gmail.com  Hari  Aineri

# %%
people_df.columns = people_df.columns.str.upper()

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST
# 0    HariAineri@gmail.com   Hari   Aineri
# 1  CareySchafer@gmail.com  Carey  Schafer

# %%
people_df.loc[0] = people_df.loc[0].str.lower()

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   aineri
# 1  CareySchafer@gmail.com  Carey  Schafer

# %%
people_df['LAST'] = people_df['LAST'].str.upper()

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   AINERI
# 1  CareySchafer@gmail.com  Carey  SCHAFER

# %%
people_df.loc[0, 'LAST'] = 'Aineri'

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   Aineri
# 1  CareySchafer@gmail.com  Carey  SCHAFER

# %%
def lower(x):
    return x.lower()

# %%
people_df['LAST'] = people_df['LAST'].apply(lower)

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   aineri
# 1  CareySchafer@gmail.com  Carey  schafer

# %%
people_df['LAST'] = people_df['LAST'].apply(lambda x: x.upper())

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   AINERI
# 1  CareySchafer@gmail.com  Carey  SCHAFER

# %%
people_df.apply(lambda x: x.str.lower())
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   aineri
# 1  careyschafer@gmail.com  carey  schafer

# %%
people_df.apply(pd.Series.min)
# Out:
# EMAIL    CareySchafer@gmail.com
# FIRST                     Carey
# LAST                     AINERI
# dtype: object

# %%
people_df.apply(lambda x: x.min())
# Out:
# EMAIL    CareySchafer@gmail.com
# FIRST                     Carey
# LAST                     AINERI
# dtype: object

# %%
people_df.applymap(len)
# Out:
# /var/folders/fs/bcwgzbxx67v_spfgx8d1s8640000gn/T/ipykernel_999/4252434392.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   people_df.applymap(len)
#    EMAIL  FIRST  LAST
# 0     20      4     6
# 1     22      5     7

# %%
people_df.map(len)
# Out:
#    EMAIL  FIRST  LAST
# 0     20      4     6
# 1     22      5     7

# %%
people_df.map(lambda x: x.lower())
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   aineri
# 1  careyschafer@gmail.com  carey  schafer

# %%
people_df.map(str.lower)
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   aineri
# 1  careyschafer@gmail.com  carey  schafer

# %%
people_df['FIRST'].map({'hari': 'Hari'})
# Out:
# 0    Hari
# 1     NaN
# Name: FIRST, dtype: object

# %%
people_df['FIRST'].replace({'hari': 'Hari'})
# Out:
# 0     Hari
# 1    Carey
# Name: FIRST, dtype: object

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST
# 0    hariaineri@gmail.com   hari   AINERI
# 1  CareySchafer@gmail.com  Carey  SCHAFER

# %%
people_df['FULL_NAME'] = people_df['FIRST'] + ' ' + people_df['LAST']

# %%
people_df
# Out:
#                     EMAIL  FIRST     LAST      FULL_NAME
# 0    hariaineri@gmail.com   hari   AINERI    hari AINERI
# 1  CareySchafer@gmail.com  Carey  SCHAFER  Carey SCHAFER

# %%
people_df.drop(columns=['FIRST', 'LAST'], inplace=True)

# %%
people_df
# Out:
#                     EMAIL      FULL_NAME
# 0    hariaineri@gmail.com    hari AINERI
# 1  CareySchafer@gmail.com  Carey SCHAFER

# %%
people_df.columns = [x.lower() for x in people_df.columns]

# %%
people_df = people_df.map(str.lower)

# %%
people_df
# Out:
#                     email      full_name
# 0    hariaineri@gmail.com    hari aineri
# 1  careyschafer@gmail.com  carey schafer

# %%
people_df['full_name'].str.split(expand=True)
# Out:
#        0        1
# 0   hari   aineri
# 1  carey  schafer

# %%
people_df[['first', 'last']] = people_df['full_name'].str.split(expand=True)

# %%
people_df
# Out:
#                     email      full_name  first     last
# 0    hariaineri@gmail.com    hari aineri   hari   aineri
# 1  careyschafer@gmail.com  carey schafer  carey  schafer

# %%
people_df = people_df._append({'first': 'lohith'}, ignore_index=True)

# %%
people_df
# Out:
#                     email      full_name   first     last
# 0    hariaineri@gmail.com    hari aineri    hari   aineri
# 1  careyschafer@gmail.com  carey schafer   carey  schafer
# 2                     NaN            NaN  lohith      NaN

# %%
new_people = {
    "first": ["tony", "steve"],
    "last": ["stark", "rogers"],
    "email": ["ironman@avenge.com", "cap@avenge.com"]
}

# %%
new_people_df = pd.DataFrame(new_people)

# %%
new_people_df
# Out:
#    first    last               email
# 0   tony   stark  ironman@avenge.com
# 1  steve  rogers      cap@avenge.com

# %%
people_df._append(new_people_df, ignore_index=True)
# Out:
#                     email      full_name   first     last
# 0    hariaineri@gmail.com    hari aineri    hari   aineri
# 1  careyschafer@gmail.com  carey schafer   carey  schafer
# 2                     NaN            NaN  lohith      NaN
# 3      ironman@avenge.com            NaN    tony    stark
# 4          cap@avenge.com            NaN   steve   rogers

# %%
people_df = people_df._append(new_people_df, ignore_index=True)

# %%
people_df
# Out:
#                     email      full_name   first     last
# 0    hariaineri@gmail.com    hari aineri    hari   aineri
# 1  careyschafer@gmail.com  carey schafer   carey  schafer
# 2                     NaN            NaN  lohith      NaN
# 3      ironman@avenge.com            NaN    tony    stark
# 4          cap@avenge.com            NaN   steve   rogers

# %%
people_df.drop(index=2)
# Out:
#                     email      full_name  first     last
# 0    hariaineri@gmail.com    hari aineri   hari   aineri
# 1  careyschafer@gmail.com  carey schafer  carey  schafer
# 3      ironman@avenge.com            NaN   tony    stark
# 4          cap@avenge.com            NaN  steve   rogers

# %%
filt = (people_df['last'] == 'rogers')
people_df.loc[filt].drop(index=people_df[filt].index)
# Out:
# Empty DataFrame
# Columns: [email, full_name, first, last]
# Index: []

# %%
filt = (people_df['last'] == 'rogers')
people_df.drop(index=people_df[filt].index)
# Out:
#                     email      full_name   first     last
# 0    hariaineri@gmail.com    hari aineri    hari   aineri
# 1  careyschafer@gmail.com  carey schafer   carey  schafer
# 2                     NaN            NaN  lohith      NaN
# 3      ironman@avenge.com            NaN    tony    stark

# %%
people_df.sort_values(by='last', ascending=False)
# Out:
#                     email      full_name   first     last
# 3      ironman@avenge.com            NaN    tony    stark
# 1  careyschafer@gmail.com  carey schafer   carey  schafer
# 4          cap@avenge.com            NaN   steve   rogers
# 0    hariaineri@gmail.com    hari aineri    hari   aineri
# 2                     NaN            NaN  lohith      NaN

# %%
people_df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
people_df.sort_index()
# Out:
#                     email      full_name   first     last
# 0    hariaineri@gmail.com    hari aineri    hari   aineri
# 1  careyschafer@gmail.com  carey schafer   carey  schafer
# 2                     NaN            NaN  lohith      NaN
# 3      ironman@avenge.com            NaN    tony    stark
# 4          cap@avenge.com            NaN   steve   rogers

# %%
df['ConvertedCompYearly'].nlargest(10)
# Out:
# ResponseId
# 53269    74351432.0
# 77849    73607918.0
# 66224    72714292.0
# 28122    57513831.0
# 19680    36573181.0
# 55103    17612921.0
# 80587    11000000.0
# 83680    10319366.0
# 47798     9915585.0
# 88348     9203683.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].nsmallest(10)
# Out:
# ResponseId
# 2244     1.0
# 3930     1.0
# 5725     1.0
# 8863     1.0
# 13709    1.0
# 17986    1.0
# 37161    1.0
# 37315    1.0
# 41417    1.0
# 47424    1.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10, 'ConvertedCompYearly')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 53269       I agree                     I am a developer by profession
# 77849       I agree                     I am a developer by profession
# 66224       I agree                     I am a developer by profession
# 28122       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 55103       I agree  I am not primarily a developer, but I write co...
# 80587       I agree                     I am a developer by profession
# 83680       I agree                     I am a developer by profession
# 47798       I agree                     I am a developer by profession
# 88348       I agree                     I am a developer by profession
#
#                            Age  \
# ResponseId
# 53269          18-24 years old
# 77849          35-44 years old
# 66224          55-64 years old
# ...

# %%
df['ConvertedCompYearly'].median()
# Out:
# 74963.0

# %%
df['ConvertedCompYearly'].mean()
# Out:
# 103110.08171765343

# %%
df['ConvertedCompYearly'].mode()
# Out:
# 0    64254.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].describe()
# Out:
# count    4.801900e+04
# mean     1.031101e+05
# std      6.814188e+05
# min      1.000000e+00
# 25%      4.390700e+04
# 50%      7.496300e+04
# 75%      1.216410e+05
# max      7.435143e+07
# Name: ConvertedCompYearly, dtype: float64

# %%
df.describe()
# Out:
#           CompTotal       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df.mode()
# Out:
#       Q120                      MainBranch              Age  \
# 0  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork CodingActivities  \
# 0  Employed, full-time  Hybrid (some remote, some in-person)            Hobby
#
#                                         EdLevel  \
# 0  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0  Formal documentation provided by the owner of ...                Udemy
#
#   YearsCode YearsCodePro                DevType             OrgSize  \
# 0        10            5  Developer, full-stack  20 to 99 employees
#
#        PurchaseInfluence     TechList  \
# 0  I have some influence  Investigate
#
#                                           BuyNewTool  \
# ...

# %%
df['ConvertedCompYearly'].agg(['median', 'mean'])
# Out:
# median     74963.000000
# mean      103110.081718
# Name: ConvertedCompYearly, dtype: float64

# %%
df.agg(['mode'])
# Out:
#       Q120                      MainBranch              Age  \
#       mode                            mode             mode
# 0  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork CodingActivities  \
#                   mode                                  mode             mode
# 0  Employed, full-time  Hybrid (some remote, some in-person)            Hobby
#
#                                         EdLevel  \
#                                            mode
# 0  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
#                                                 mode
# 0  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
#                                                 mode                 mode
# 0  Formal documentation provided by the owner of ...                Udemy
#
# ...

# %%
country_grp = df.groupby(['Country'])

# %%
india_df = country_grp.get_group(('India',))
india_df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 10          I agree  I am a developer by profession  25-34 years old
# 67          I agree  I am a developer by profession  25-34 years old
# 79          I agree  I am a developer by profession  18-24 years old
# 83          I agree  I am a developer by profession  25-34 years old
# 86          I agree  I am a developer by profession  25-34 years old
#
#                                     Employment  \
# ResponseId
# 10          Not employed, but looking for work
# 67                         Employed, full-time
# 79                         Employed, full-time
# 83                         Employed, full-time
# 86                         Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 10                                           NaN
# 67          Hybrid (some remote, some in-person)
# 79                                        Remote
# ...

# %%
country_grp['MainBranch'].value_counts()
# Out:
# Country      MainBranch
# Afghanistan  I am a developer by profession                                                           40
#              I am learning to code                                                                    11
#              I am not primarily a developer, but I write code sometimes as part of my work/studies     7
#              I code primarily as a hobby                                                               5
#              I used to be a developer by profession, but no longer am                                  1
#                                                                                                       ..
# Zambia       I code primarily as a hobby                                                               3
# Zimbabwe     I am a developer by profession                                                           17
#              I am learning to code                                                                    10
# ...

# %%
country_grp['ConvertedCompYearly'].median()
# Out:
# Country
# Afghanistan                               915.0
# Albania                                 10741.0
# Algeria                                  8782.0
# Andorra                                 42836.0
# Angola                                   4302.0
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                12763.0
# Yemen                                    6500.0
# Zambia                                   9687.0
# Zimbabwe                                12500.0
# Name: ConvertedCompYearly, Length: 185, dtype: float64

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18647
# Germany                                              7328
# India                                                5625
# United Kingdom of Great Britain and Northern Ir...   5552
# Canada                                               3507
# ...                                                   ...
# Saint Kitts and Nevis                                   1
# Marshall Islands                                        1
# Samoa                                                   1
# Central African Republic                                1
# San Marino                                              1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
python_df.rename(columns={'count':'NumRespondents', 'LanguageHaveWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)
python_df
# Out:
#                                        NumRespondents  NumKnowsPython  \
# Country
# San Marino                                          1               1
# North Korea                                         4               4
# Samoa                                               1               1
# Liechtenstein                                       1               1
# Grenada                                             1               1
# ...                                               ...             ...
# Guinea                                              2               0
# Monaco                                              2               0
# Bahamas                                             2               0
# Niger                                               4               0
# Democratic People's Republic of Korea               2               0
#
#                                        PctKnowsPython
# Country
# ...

# %%
import numpy as np

# %%
people = {
    'first': ['Hari', 'Carey', np.nan, None, 'NA'],
    'last': ['Aineri', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': ['HariAineri@email.com', 'CareySchafer@email.com', None, 'abc@email.com', 'NA'],
    'Age': [34, 35, 36, None, 'NA']
}

# %%
people_missing_value_df = pd.DataFrame(people)

# %%
people_missing_value_df
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com    34
# 1  Carey  Schafer  CareySchafer@email.com    35
# 2    NaN      NaN                    None    36
# 3   None      NaN           abc@email.com  None
# 4     NA  Missing                      NA    NA

# %%
people_missing_value_df.replace(np.nan, "Missing")
# Out:
#      first     last                   email      Age
# 0     Hari   Aineri    HariAineri@email.com       34
# 1    Carey  Schafer  CareySchafer@email.com       35
# 2  Missing  Missing                 Missing       36
# 3  Missing  Missing           abc@email.com  Missing
# 4       NA  Missing                      NA       NA

# %%
people_missing_value_df.dropna()
# Out:
#    first     last                   email Age
# 0   Hari   Aineri    HariAineri@email.com  34
# 1  Carey  Schafer  CareySchafer@email.com  35
# 4     NA  Missing                      NA  NA

# %%
people_missing_value_df.dropna(axis='columns', how='all')
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com    34
# 1  Carey  Schafer  CareySchafer@email.com    35
# 2    NaN      NaN                    None    36
# 3   None      NaN           abc@email.com  None
# 4     NA  Missing                      NA    NA

# %%
people_missing_value_df.dropna(axis='index', how='any', subset=['Age'])
# Out:
#    first     last                   email Age
# 0   Hari   Aineri    HariAineri@email.com  34
# 1  Carey  Schafer  CareySchafer@email.com  35
# 2    NaN      NaN                    None  36
# 4     NA  Missing                      NA  NA

# %%
people_missing_value_df.isna()
# Out:
#    first   last  email    Age
# 0  False  False  False  False
# 1  False  False  False  False
# 2   True   True   True  False
# 3   True   True  False   True
# 4  False  False  False  False

# %%
people_missing_value_df.fillna(0)
# Out:
#    first     last                   email Age
# 0   Hari   Aineri    HariAineri@email.com  34
# 1  Carey  Schafer  CareySchafer@email.com  35
# 2      0        0                       0  36
# 3      0        0           abc@email.com   0
# 4     NA  Missing                      NA  NA

# %%
people_missing_value_df.dtypes
# Out:
# first    object
# last     object
# email    object
# Age      object
# dtype: object

# %%
people_missing_value_df.replace('NA', np.nan, inplace=True)
people_missing_value_df.replace('Missing', np.nan, inplace=True)
# Out:
# /var/folders/fs/bcwgzbxx67v_spfgx8d1s8640000gn/T/ipykernel_999/926638514.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   people_missing_value_df.replace('NA', np.nan, inplace=True)

# %%
people_missing_value_df
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com  34.0
# 1  Carey  Schafer  CareySchafer@email.com  35.0
# 2    NaN      NaN                    None  36.0
# 3   None      NaN           abc@email.com   NaN
# 4    NaN      NaN                     NaN   NaN

# %%
people_missing_value_df.dtypes
# Out:
# first     object
# last      object
# email     object
# Age      float64
# dtype: object

# %%
people_missing_value_df.fillna(0)
# Out:
#    first     last                   email   Age
# 0   Hari   Aineri    HariAineri@email.com  34.0
# 1  Carey  Schafer  CareySchafer@email.com  35.0
# 2      0        0                       0  36.0
# 3      0        0           abc@email.com   0.0
# 4      0        0                       0   0.0

# %%
people_missing_value_df['Age'].mean()
# Out:
# 35.0

# %%
date_series_df = pd.read_csv('ETH_1h.csv')

# %%
date_series_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
date_series_df.loc[0, 'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 date_series_df.loc[0, 'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
date_series_df['Date'] = pd.to_datetime(date_series_df['Date'], format='%Y-%m-%d %I-%p')

# %%
date_series_df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
date_series_df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
d_df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
d_df.head()
# Out:
# /var/folders/fs/bcwgzbxx67v_spfgx8d1s8640000gn/T/ipykernel_999/836979292.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   d_df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/parsers/base_parser.py:1190, in _make_date_converter.<locals>.converter(col, *date_cols)
#    1184 warnings.filterwarnings(
#    1185     "ignore",
#    1186     ".*parsing datetimes with mixed time zones "
#    1187     "will raise an error",
#    1188     category=FutureWarning,
#    1189 )
# -> 1190 pre_parsed = date_parser(
# ...

# %%
date_series_df['DayOfWeek'] = date_series_df['Date'].dt.day_name()

# %%
date_series_df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfWeek
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %%
date_series_df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
date_series_df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
date_series_df['Date'].max() - date_series_df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = date_series_df['Date'] >= '2020'
date_series_df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt = (date_series_df['Date'] >= pd.to_datetime('2019-01-01')) & (date_series_df['Date'] < pd.to_datetime('2020-01-01'))
date_series_df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
date_series_df.set_index('Date', inplace=True)
date_series_df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
date_series_df.loc['2020-01']
# Out:
#                      Symbol    Open    High     Low   Close     Volume  \
# Date
# 2020-01-31 23:00:00  ETHUSD  181.73  181.73  179.00  179.74  438575.26
# 2020-01-31 22:00:00  ETHUSD  180.66  182.24  180.03  181.73  754254.39
# 2020-01-31 21:00:00  ETHUSD  180.31  181.04  179.98  180.66  657922.36
# 2020-01-31 20:00:00  ETHUSD  179.19  180.51  179.13  180.31  979846.20
# 2020-01-31 19:00:00  ETHUSD  179.10  179.57  178.71  179.19  353169.87
# ...                     ...     ...     ...     ...     ...        ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56  702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57  496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37  396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14  635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34  245119.91
#
#                      DayOfWeek
# Date
# 2020-01-31 23:00:00     Friday
# 2020-01-31 22:00:00     Friday
# ...

# %%
date_series_df.loc['2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-02-01 04:00:00  ETHUSD  183.16  183.49  181.34  181.74   706490.86
# 2020-02-01 03:00:00  ETHUSD  183.61  183.81  182.41  183.16   279177.55
# 2020-02-01 02:00:00  ETHUSD  183.59  184.00  181.93  183.61  1829192.09
# 2020-02-01 01:00:00  ETHUSD  181.06  183.64  180.98  183.59   946295.21
# 2020-02-01 00:00:00  ETHUSD  179.74  181.41  179.00  181.06   637332.52
#
#                     DayOfWeek
# Date
# 2020-02-29 23:00:00  Saturday
# ...

# %%
n_df = pd.concat([date_series_df.loc['2020-02'], date_series_df.loc['2020-01']])
n_df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
n_df['Close'].agg(['mean', 'median'])
# Out:
# pandas.core.series.Series

# %%
n_df['Close'].agg(['mode'])
# Out:
#      mode
# 0  143.59

# %%
lows = date_series_df['Low'].resample('D').max()

# %%
highs = date_series_df['High'].resample('D').max()

# %%
close = date_series_df['Close'].resample('D').max()

# %%
volume = date_series_df['Volume'].resample('D').max()

# %%
dayOfWeek = date_series_df['DayOfWeek'].resample('D').max()

# %%
symbol = date_series_df['Symbol'].resample('D').max()

# %%
open = date_series_df['Open'].resample('D').max()

# %%
df = pd.concat([symbol, open, highs, lows, close, volume, dayOfWeek], axis='columns', sort=True)

# %%
df
# Out:
#             Symbol    Open    High     Low   Close       Volume  DayOfWeek
# Date
# 2017-07-01  ETHUSD  279.98  279.99  272.10  275.01   5396852.35   Saturday
# 2017-07-02  ETHUSD  292.54  293.73  284.87  292.54   7081816.11     Sunday
# 2017-07-03  ETHUSD  285.00  285.00  280.60  282.36   3485745.42     Monday
# 2017-07-04  ETHUSD  282.58  282.83  282.31  282.58   4874310.69    Tuesday
# 2017-07-05  ETHUSD  271.00  274.97  269.25  271.00   6082287.50  Wednesday
# ...            ...     ...     ...     ...     ...          ...        ...
# 2020-03-09  ETHUSD  207.79  208.65  205.83  207.79   9973969.49     Monday
# 2020-03-10  ETHUSD  205.79  206.28  203.02  205.79   4273768.87    Tuesday
# 2020-03-11  ETHUSD  202.48  202.98  201.35  202.48   7425363.13  Wednesday
# 2020-03-12  ETHUSD  194.61  195.64  192.02  193.44  19731142.71   Thursday
# 2020-03-13  ETHUSD  134.03  148.00  128.99  134.03  19431820.56     Friday
#
# [987 rows x 7 columns]

# %%
df.loc['2020-01-01']
# Out:
# Symbol           ETHUSD
# Open             132.55
# High             132.68
# Low              131.94
# Close            132.55
# Volume       1168999.08
# DayOfWeek     Wednesday
# Name: 2020-01-01 00:00:00, dtype: object

# %%
date_series_df.resample('D').max()
# Out:
#             Symbol    Open    High     Low   Close       Volume  DayOfWeek
# Date
# 2017-07-01  ETHUSD  279.98  279.99  272.10  275.01   5396852.35   Saturday
# 2017-07-02  ETHUSD  292.54  293.73  284.87  292.54   7081816.11     Sunday
# 2017-07-03  ETHUSD  285.00  285.00  280.60  282.36   3485745.42     Monday
# 2017-07-04  ETHUSD  282.58  282.83  282.31  282.58   4874310.69    Tuesday
# 2017-07-05  ETHUSD  271.00  274.97  269.25  271.00   6082287.50  Wednesday
# ...            ...     ...     ...     ...     ...          ...        ...
# 2020-03-09  ETHUSD  207.79  208.65  205.83  207.79   9973969.49     Monday
# 2020-03-10  ETHUSD  205.79  206.28  203.02  205.79   4273768.87    Tuesday
# 2020-03-11  ETHUSD  202.48  202.98  201.35  202.48   7425363.13  Wednesday
# 2020-03-12  ETHUSD  194.61  195.64  192.02  193.44  19731142.71   Thursday
# 2020-03-13  ETHUSD  134.03  148.00  128.99  134.03  19431820.56     Friday
#
# [987 rows x 7 columns]

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <Axes: xlabel='Date'>
